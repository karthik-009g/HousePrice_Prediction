# %% [markdown]
# 🏁 Summary Table
# Step	Status	Your Action
# Problem Statement	✅	Add markdown summary
# Load + Initial View	✅	Good
# Data Overview	🔁	Add .info(), .nunique()
# EDA	❌	Must add plots for SalePrice, numerical, categorical
# Null Analysis	🔁	Visualize, group types
# Cleaning	🔁	Justify dropping, fill more clearly
# Feature Grouping	❌	Build ordinal, nominal, numerical lists
# Feature Engineering	❌	Encode, create new features
# Feature Selection	❌	Use correlation, model importance
# Train-Test Split	❌	Add train_test_split()
# Modeling	❌	Try 3–4 regressors
# Evaluation	❌	RMSE, R², residual plots
# Hyperparameter Tuning	❌	Use GridSearchCV
# Final Pipeline	❌	Wrap with Pipeline, save model
# Deployment	❌	Optional — use Streamlit or Flask

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows",1500)
pd.set_option("display.max_columns",90)

# %%
df = pd.read_csv(r"C:\HousePrice_prediction\train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# Exploratory Data Anlaysis
# step 1 target variable analysis
# step 2 Numerical Feature Exploration
# step 3 Categorical Feature Exploration
# step 4 Correlation Analysis
# step 5 Outlier Detection

# %%
#Target Variable Analysis - Analyse SalePrice with 
sns.histplot(df['SalePrice'],kde = True)
# Out:
# C:\Users\gubba\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
#Since it is right skewed we have to check its skew
df['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
# since its highly skewed we have to apply log1p to make the distribuution normal
df['SalePrice'] = np.log1p(df['SalePrice'])
sns.histplot(df['SalePrice'],kde =True)
# Out:
# C:\Users\gubba\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
df['SalePrice'].skew()
# Out:
# 0.12134661989685333

# %%
#step 2 seperate numerical and categorical data 
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
numerical = df.select_dtypes(include = ['float64','int64']).columns

# %%
correlation_matrix =df[numerical].corr()['SalePrice'].sort_values(ascending = False)
print(correlation_matrix)
# Out:
# SalePrice        1.000000
# OverallQual      0.817185
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489450
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355879
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209043
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057330
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# OverallCond     -0.036868
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# ...

# %%
#top correlated features are OverallQual      0.817185
#GrLivArea        0.700927
#GarageCars       0.680625
#so now analyse them against the target
sns.scatterplot(x = df['GrLivArea'], y = df['SalePrice'])
plt.title('GrLivArea vs SalePrice')
plt.show()

# %%
sns.boxplot(x =df['GarageCars'], y = df['SalePrice'],)
plt.show()

# %%
sns.boxplot(x = df['OverallQual'], y = df['SalePrice'])
plt.show()

# %%
#Categorical Data

# %% [markdown]
# #observation 1
# outliers present in
# mssubclass
# lotfrontage
# lotarea
# masvnrarea
# bsmtfinsf1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtHalfBath
# TotRmsAbvGrd
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# SalePrice

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# #observation 2
# dropping theses features will be better as more than 50 % data is missing
# Alley            1369
# MasVnrType        872
# PoolQC           1453
# Fence            1179
# MiscFeature      1406

# %%
#handeling LotFrontage       259null values by filling mean value of that column
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1    2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2    3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3    4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4    5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5    6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6    7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7    8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8    9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9   10         190       RL    50.000000     7420   Pave   NaN      Reg
# 10  11          20       RL    70.000000    11200   Pave   NaN      Reg
# 11  12          60       RL    85.000000    11924   Pave   NaN      IR1
# ...

# %%
df.drop(columns = 'Alley',inplace = True)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.drop(columns = 'MasVnrType' ,inplace = True)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.drop(columns = 'PoolQC',inplace = True)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.drop(columns = 'Fence',inplace = True)

# %%
df.drop(columns = 'MiscFeature',inplace = True)

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')

# %%
df['BsmtQual'] = df['BsmtQual'].fillna('None')

# %%
df['BsmtCond'] = df['BsmtCond'].fillna('None')
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# 5    6          50       RL    85.000000    14115   Pave      IR1         Lvl
# 6    7          20       RL    75.000000    10084   Pave      Reg         Lvl
# 7    8          60       RL    70.049958    10382   Pave      IR1         Lvl
# 8    9          50       RM    51.000000     6120   Pave      Reg         Lvl
# 9   10         190       RL    50.000000     7420   Pave      Reg         Lvl
# 10  11          20       RL    70.000000    11200   Pave      Reg         Lvl
# ...

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna('None')
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# 5    6          50       RL    85.000000    14115   Pave      IR1         Lvl
# 6    7          20       RL    75.000000    10084   Pave      Reg         Lvl
# 7    8          60       RL    70.049958    10382   Pave      IR1         Lvl
# 8    9          50       RM    51.000000     6120   Pave      Reg         Lvl
# 9   10         190       RL    50.000000     7420   Pave      Reg         Lvl
# 10  11          20       RL    70.000000    11200   Pave      Reg         Lvl
# ...

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('None')
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# 5    6          50       RL    85.000000    14115   Pave      IR1         Lvl
# 6    7          20       RL    75.000000    10084   Pave      Reg         Lvl
# 7    8          60       RL    70.049958    10382   Pave      IR1         Lvl
# 8    9          50       RM    51.000000     6120   Pave      Reg         Lvl
# 9   10         190       RL    50.000000     7420   Pave      Reg         Lvl
# 10  11          20       RL    70.000000    11200   Pave      Reg         Lvl
# ...

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('None')
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# 5    6          50       RL    85.000000    14115   Pave      IR1         Lvl
# 6    7          20       RL    75.000000    10084   Pave      Reg         Lvl
# 7    8          60       RL    70.049958    10382   Pave      IR1         Lvl
# 8    9          50       RM    51.000000     6120   Pave      Reg         Lvl
# 9   10         190       RL    50.000000     7420   Pave      Reg         Lvl
# 10  11          20       RL    70.000000    11200   Pave      Reg         Lvl
# ...

# %%
df.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage       0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual          0
# BsmtCond          0
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinSF1        0
# BsmtFinType2      0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# ...

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
df['GarageType'] = df['GarageType'].fillna('None')

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# %%
df['GarageFinish'] = df['GarageFinish'].fillna('None')

# %%
df['GarageQual'] = df['GarageQual'].fillna('None')

# %%
df['GarageCond'] = df['GarageCond'].fillna('None')

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
#based on observation  we have to perform feature engineering on the dataset to get better accuracy in machine learning model

# %%
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# 5    6          50       RL    85.000000    14115   Pave      IR1         Lvl
# 6    7          20       RL    75.000000    10084   Pave      Reg         Lvl
# 7    8          60       RL    70.049958    10382   Pave      IR1         Lvl
# 8    9          50       RM    51.000000     6120   Pave      Reg         Lvl
# 9   10         190       RL    50.000000     7420   Pave      Reg         Lvl
# 10  11          20       RL    70.000000    11200   Pave      Reg         Lvl
# ...

# %%
df['Street'].value_counts(normalize = True)
# Out:
# Street
# Pave    0.99589
# Grvl    0.00411
# Name: proportion, dtype: float64

# %%
#since it will cause overfitting removing is best

# %%
df.drop(columns = 'Street',axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0   1          60       RL         65.0     8450      Reg         Lvl
# 1   2          20       RL         80.0     9600      Reg         Lvl
# 2   3          60       RL         68.0    11250      IR1         Lvl
# 3   4          70       RL         60.0     9550      IR1         Lvl
# 4   5          60       RL         84.0    14260      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# ...

# %%
categorical = df.select_dtypes(include ="object").columns.tolist()
print(categorical)
# Out:
# ['MSZoning', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
#feature engineering step
